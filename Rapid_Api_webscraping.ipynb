# %% [markdown]
# <a href="https://colab.research.google.com/github/Somesh140/Web-scrapping-/blob/main/Rapid_Api_webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://visual-crossing-weather.p.rapidapi.com/forecast"

querystring = {"aggregateHours":"24","location":"Delhi,India","contentType":"csv","unitGroup":"us","shortColumnNames":"0"}

headers = {
	"X-RapidAPI-Key": "e53d40f1e3msh1f2eb93c6599e14p14b10fjsnad0bbbe3bceb",
	"X-RapidAPI-Host": "visual-crossing-weather.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# Address,Date time,Latitude,Longitude,Resolved Address,Name,Wind Direction,Minimum Temperature,Maximum Temperature,Temperature,Wind Speed,Cloud Cover,Heat Index,Chance Precipitation (%),Precipitation,Sea Level Pressure,Snow Depth,Snow,Relative Humidity,Wind Gust,Wind Chill,Conditions
# "Delhi,India","02/02/2023",28.6341,77.2169,"Delhi, DL, India","Delhi,India",307.0,60.2,74.6,67.5,7.5,0.0,,0.0,0.0,1015.1,0.0,0.0,35.4,17.4,,"Clear"
# "Delhi,India","02/03/2023",28.6341,77.2169,"Delhi, DL, India","Delhi,India",295.8,54.6,75.6,64.1,6.3,0.2,,0.0,0.0,1015.1,0.0,0.0,36.0,15.9,,"Clear"
# "Delhi,India","02/04/2023",28.6341,77.2169,"Delhi, DL, India","Delhi,India",294.1,56.6,77.3,65.8,6.7,0.0,,0.0,0.0,1012.7,0.0,0.0,36.6,15.2,,"Clear"
# "Delhi,India","02/05/2023",28.6341,77.2169,"Delhi, DL, India","Delhi,India",262.2,57.3,77.8,66.4,5.7,0.0,,0.0,0.0,1012.1,0.0,0.0,38.9,13.4,,"Clear"
# ...

# %%
l=response.text.split(",")

# %%
import pandas as pd
pd.DataFrame(l)
# Out:
#                         0
# 0                 Address
# 1               Date time
# 2                Latitude
# 3               Longitude
# 4        Resolved Address
# ..                    ...
# 417                   0.0
# 418                  25.0
# 419                  17.4
# 420
# 421  "Partially cloudy"\n
#
# [422 rows x 1 columns]

# %%
with open("weather.txt","w") as f:
  f.write(response.text)

# %%
pd.read_csv("/content/weather.txt")
# Out:
#         Address   Date time  Latitude  Longitude  Resolved Address  \
# 0   Delhi,India  02/02/2023   28.6341    77.2169  Delhi, DL, India
# 1   Delhi,India  02/03/2023   28.6341    77.2169  Delhi, DL, India
# 2   Delhi,India  02/04/2023   28.6341    77.2169  Delhi, DL, India
# 3   Delhi,India  02/05/2023   28.6341    77.2169  Delhi, DL, India
# 4   Delhi,India  02/06/2023   28.6341    77.2169  Delhi, DL, India
# 5   Delhi,India  02/07/2023   28.6341    77.2169  Delhi, DL, India
# 6   Delhi,India  02/08/2023   28.6341    77.2169  Delhi, DL, India
# 7   Delhi,India  02/09/2023   28.6341    77.2169  Delhi, DL, India
# 8   Delhi,India  02/10/2023   28.6341    77.2169  Delhi, DL, India
# 9   Delhi,India  02/11/2023   28.6341    77.2169  Delhi, DL, India
# 10  Delhi,India  02/12/2023   28.6341    77.2169  Delhi, DL, India
# 11  Delhi,India  02/13/2023   28.6341    77.2169  Delhi, DL, India
# 12  Delhi,India  02/14/2023   28.6341    77.2169  Delhi, DL, India
# ...

# %%
import requests

url = "https://visual-crossing-weather.p.rapidapi.com/forecast"

querystring = {"aggregateHours":"24","location":"Delhi,India","contentType":"json","unitGroup":"us","shortColumnNames":"0"}

headers = {
	"X-RapidAPI-Key": "e53d40f1e3msh1f2eb93c6599e14p14b10fjsnad0bbbe3bceb",
	"X-RapidAPI-Host": "visual-crossing-weather.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"columns":{"wdir":{"id":"wdir","name":"Wind Direction","type":2,"unit":null},"uvindex":{"id":"uvindex","name":"weather_uvindex","type":2,"unit":null},"latitude":{"id":"latitude","name":"Latitude","type":2,"unit":null},"preciptype":{"id":"preciptype","name":"weather_preciptype","type":1,"unit":null},"cin":{"id":"cin","name":"weather_cin","type":2,"unit":null},"cloudcover":{"id":"cloudcover","name":"Cloud Cover","type":2,"unit":null},"pop":{"id":"pop","name":"Chance Precipitation (%)","type":2,"unit":null},"mint":{"id":"mint","name":"Minimum Temperature","type":2,"unit":"degF"},"datetime":{"id":"datetime","name":"Date time","type":3,"unit":null},"precip":{"id":"precip","name":"Precipitation","type":2,"unit":"in"},"solarradiation":{"id":"solarradiation","name":"Solar Radiation","type":2,"unit":null},"dew":{"id":"dew","name":"Dew Point","type":2,"unit":"degf"},"humidity":{"id":"humidity","name":"Relative Humidity","type":2,"unit":null},"longitude":{"id":"longitude","name":"Longitude","t
# ...

# %%
pd.DataFrame(response.json()['locations'])[['']]
# Out:
#                                                             Delhi,India
# address                                                Delhi, DL, India
# alerts                                                             None
# currentConditions     {'wdir': 270.0, 'temp': 70.3, 'sunrise': '2023...
# distance                                                            0.0
# id                                                          Delhi,India
# index                                                                 0
# latitude                                                        28.6341
# longitude                                                       77.2169
# name                                                        Delhi,India
# stationContributions                                               None
# time                                                                0.0
# tz                                                         Asia/Kolkata
# ...

# %%
pd.DataFrame(response.json()['locations']['Delhi,India']['values'])
# Out:
#      wdir  uvindex                datetimeStr preciptype  cin  cloudcover  \
# 0   307.0      2.0  2023-02-02T00:30:00+05:30             0.0         0.0
# 1   295.8      1.8  2023-02-03T00:30:00+05:30             0.0         0.2
# 2   294.1      1.8  2023-02-04T00:30:00+05:30             0.0         0.0
# 3   262.2      1.8  2023-02-05T00:30:00+05:30             0.0         0.0
# 4   255.7      1.8  2023-02-06T00:30:00+05:30             0.0         0.0
# 5   300.3      1.8  2023-02-07T00:30:00+05:30             0.1         0.0
# 6   305.3      1.8  2023-02-08T00:30:00+05:30             0.0         1.5
# 7   303.9      1.9  2023-02-09T00:30:00+05:30             0.0         0.0
# 8   278.8      1.9  2023-02-10T00:30:00+05:30             0.0         0.0
# 9   232.0      1.9  2023-02-11T00:30:00+05:30             0.0         0.6
# 10  321.6      1.9  2023-02-12T00:30:00+05:30             0.0         0.0
# 11  301.7      2.0  2023-02-13T00:30:00+05:30             0.0         0.0
# ...
